# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel("nlsw88.xlsx")

# %%
df
# Out:
#       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2241    5153   35  White   Single     Never married   12.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff=df.dropna()

# %%
dff
# Out:
#       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2240    5152   35  White  Married  Has been married   13.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff.describe()
# Out:
#             idcode          age        grade         wage        hours  \
# count  1849.000000  1849.000000  1849.000000  1849.000000  1849.000000
# mean   2612.971336    39.215792    13.171444     7.604570    37.620335
# std    1487.148673     3.041283     2.550003     4.172752     9.955243
# min       1.000000    34.000000     0.000000     1.344605     1.000000
# 25%    1349.000000    37.000000    12.000000     4.629630    35.000000
# 50%    2659.000000    39.000000    12.000000     6.634459    40.000000
# 75%    3893.000000    42.000000    15.000000     9.758451    40.000000
# max    5159.000000    46.000000    18.000000    39.230740    80.000000
#
#            ttl_exp       tenure
# count  1849.000000  1849.000000
# mean     12.864414     6.579998
# std       4.577041     5.631798
# min       0.403846     0.000000
# 25%       9.615385     1.916667
# 50%      13.467950     4.666667
# 75%      16.269230     9.916667
# max      28.884610    25.916670

# %%
dff["grade"].mode()
# Out:
# 0    12.0
# Name: grade, dtype: float64

# %%
dff["grade"].max()-dff["grade"].min()
# Out:
# np.float64(18.0)

# %%
dff["grade"].var()
# Out:
# np.float64(6.502517448298953)

# %%
dff["grade"].dtype
# Out:
# dtype('float64')

# %%
dff["grade"].skew()
# Out:
# np.float64(0.007485709163094047)

# %%
dff["grade"].kurtosis()
# Out:
# np.float64(0.6348012265710135)

# %%
#Plotting a histogram
plt.hist(dff["grade"],bins=100)
plt.title("grade histogram")
plt.xlabel("grade")
plt.ylabel("frequency")
plt.show()

# %%
#Plotting a boxplot
plt.boxplot(dff["grade"])
plt.title("grade boxplot")
plt.ylabel("values")
plt.show()
