# %%
#Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("nlsw88.xlsx")
dff=df.dropna()

# %%
dff
# Out:
#       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2240    5152   35  White  Married  Has been married   13.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff.describe
# Out:
# <bound method NDFrame.describe of       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2240    5152   35  White  Married  Has been married   13.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff.shape
# Out:
# (1849, 17)

# %%
dff.columns
# Out:
# Index(['idcode', 'age', 'race', 'married', 'never_married', 'grade',
#        'collgrad', 'south', 'smsa', 'c_city', 'industry', 'occupation',
#        'union', 'wage', 'hours', 'ttl_exp', 'tenure'],
#       dtype='object')

# %%
dff.isnull()
# Out:
# <bound method DataFrame.isnull of       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2240    5152   35  White  Married  Has been married   13.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff["hourly_wage"]=dff["wage"]/dff["hours"]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12996\3738469332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff["hourly_wage"]=dff["wage"]/dff["hours"]

# %%
dff
# Out:
#       idcode  age   race  married     never_married  grade          collgrad  \
# 0          1   37  Black   Single  Has been married   12.0  Not college grad
# 1          2   37  Black   Single  Has been married   12.0  Not college grad
# 2          3   42  Black   Single     Never married   12.0  Not college grad
# 3          4   43  White  Married  Has been married   17.0      College grad
# 4          6   42  White  Married  Has been married   12.0  Not college grad
# ...      ...  ...    ...      ...               ...    ...               ...
# 2240    5152   35  White  Married  Has been married   13.0  Not college grad
# 2242    5154   44  White  Married  Has been married   16.0      College grad
# 2243    5156   42  White  Married  Has been married   12.0  Not college grad
# 2244    5157   38  Black  Married  Has been married   12.0  Not college grad
# 2245    5159   43  Black   Single  Has been married   12.0  Not college grad
#
# ...

# %%
dff["hourly_wage"].mean()
# Out:
# np.float64(0.24095679532897027)

# %%
dff["hourly_wage"].median()
# Out:
# np.float64(0.18297095000000002)

# %%
dff["hourly_wage"].mode()
# Out:
# 0    0.125805
# Name: hourly_wage, dtype: float64

# %%
dff["hourly_wage"].mean()
# Out:
# np.float64(0.24095679532897027)

# %%
df["hourly_wage"].median()
# Out:
# np.float64(0.17612719999999998)

# %%
dff["hourly_wage"].mode()
# Out:
# 0    0.125805
# Name: hourly_wage, dtype: float64

# %%
dff["hourly_wage"].max()
# Out:
# np.float64(9.098225)

# %%
dff["hourly_wage"].min()
# Out:
# np.float64(0.017411425)

# %%
Range=dff["hourly wage"].max()-dff["hourly wage"].min()
Range
# Out:
# np.float64(9.080813574999999)

# %%
dff["hourly wage"].var()
# Out:
# np.float64(0.13104514604538503)

# %%
dff["hourly wage"].std()
# Out:
# np.float64(0.3620015829321538)

# %%
IQR=dff["hourly_wage"].quantile(0.75)-dff["hourly_wage"].quantile(0.25)
IQR
# Out:
# np.float64(0.13586959999999995)

# %%
dff["hourly_wage"].skew()
#
# Out:
# np.float64(13.798988559708006)

# %%
dff["hourly_wage"].kurt()
# Out:
# np.float64(266.52617491957136)

# %%
#Plot a histogram
plt.hist(dff["hourly_wage"],bins=100)
plt.title("hourly wage histogram")
plt.xlabel("hourly wage")
plt.ylabel("frequency")
plt.show()

# %%
#converting hourly wages to numeric data
dff["hourly_wage"]=pd.to_numeric(dff["hourly_wage"])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12996\208301353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff["hourly_wage"]=pd.to_numeric(dff["hourly_wage"])

# %%
dff["hourly_wage"].dtype
# Out:
# dtype('float64')

# %%
#Plotting a boxplot
plt.boxplot(dff["hourly_wage"])
plt.title("hourly wage boxplot")
plt.ylabel("values")
plt.show()

# %%
dff["hourly_wage"].describe()
# Out:
# count    1849.000000
# mean        0.240957
# std         0.362002
# min         0.017411
# 25%         0.125805
# 50%         0.182971
# 75%         0.261675
# max         9.098225
# Name: hourly_wage, dtype: float64

# %%
dff["hourly_wage"].count()
# Out:
# np.int64(1849)
